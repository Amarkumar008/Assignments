# %% [markdown]
# # Problem Statement:
#
# A Microfinance Institution (MFI) is an organization that offers financial services to low income populations. MFS becomes very useful when targeting especially the unbanked poor families living in remote areas with not much sources of income. The Microfinance services (MFS) provided by MFI are Group Loans, Agricultural Loans, Individual Business Loans and so on.
#
# Many microfinance institutions (MFI), experts and donors are supporting the idea of using mobile financial services (MFS) which they feel are more convenient and efficient, and cost saving, than the traditional high-touch model used since long for the purpose of delivering microfinance services. Though, the MFI industry is primarily focusing on low income families and are very useful in such areas, the implementation of MFS has been uneven with both significant challenges and successes.
# Today, microfinance is widely accepted as a poverty-reduction tool, representing $70 billion in outstanding loans and a global outreach of 200 million clients.
#
# We are working with one such client that is in Telecom Industry. They are a fixed wireless telecommunications network provider. They have launched various products and have developed its business and organization based on the budget operator model, offering better products at Lower Prices to all value conscious customers through a strategy of disruptive innovation that focuses on the subscriber.
#
# They understand the importance of communication and how it affects a person’s life, thus, focusing on providing their services and products to low income families and poor customers that can help them in the need of hour.
#
# They are collaborating with an MFI to provide micro-credit on mobile balances to be paid back in 5 days. The Consumer is believed to be defaulter if he deviates from the path of paying back the loaned amount within the time duration of 5 days. For the loan amount of 5 (in Indonesian Rupiah), payback amount should be 6 (in Indonesian Rupiah), while, for the loan amount of 10 (in Indonesian Rupiah), the payback amount should be 12 (in Indonesian Rupiah).
#
# The sample data is provided to us from our client database. It is hereby given to you for this exercise. In order to improve the selection of customers for the credit, the client wants some predictions that could help them in further investment and improvement in selection of customers.

# %%
#importing the libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#import the dataset

df = pd.read_csv(r'C:\Users\HP-15\Micro_credit_project.csv')

# %%
#visualizing the dataset
df
# Out:
#         Unnamed: 0  label       msisdn            aon  daily_decr30  \
# 0                1      0  21408I70789     272.000000   3055.050000
# 1                2      1  76462I70374     712.000000  12122.000000
# 2                3      1  17943I70372     535.000000   1398.000000
# 3                4      1  55773I70781     241.000000     21.228000
# 4                5      1  03813I82730     947.000000    150.619333
# 5                6      1  35819I70783     568.000000   2257.362667
# 6                7      1  96759I84459     545.000000   2876.641667
# 7                8      1  09832I90846     768.000000  12905.000000
# 8                9      1  59772I84450    1191.000000     90.695000
# 9               10      1  56331I70783     536.000000     29.357333
# 10              11      1  32893I82732    1511.000000     12.896000
# 11              12      0  82417I90848      82.000000     65.166667
# 12              13      1  11435I89236     154.000000    227.041000
# 13              14      1  66580I97601     887.000000     55.909333
# 14              15      1  63139I70377     707.000000   8919.000000
# 15              16      0  24075I89239    1037.000000     12.000000
# 16              17      0  82053I85350    1583.000000   1000.000000
# 17              18      1  37204I84452     929.000000     10.688000
# 18              19      1  44217I90455     832.000000     14.400000
# 19              20      1  19611I90842     450.000000     48.935000
# 20              21      1  67813I90589     100.000000    769.614000
# 21              22      0  75522I70784     378.000000    514.693333
# 22              23      1  61590I95202     463.000000   1540.000000
# 23              24      1  95027I90841     857.000000     58.023333
# 24              25      0  59645I82735     966.000000    291.563333
# 25              26      1  59102I70370     656.000000     63.250000
# 26              27      1  44692I90581    1179.000000   3703.272000
# 27              28      0  49345I90842     871.000000    505.600000
# 28              29      1  64703I85330    1610.000000   6688.559333
# 29              30      1  12658I88689      67.000000     16.166667
# ...            ...    ...          ...            ...           ...
# 209563      209564      1  12150I70780     574.000000     74.700000
# 209564      209565      1  45133I84455    2035.000000   8138.067333
# 209565      209566      1  94870I89230    1380.000000     33.788333
# 209566      209567      1  24083I70783     520.000000     48.555000
# 209567      209568      1  30258I95683     961.000000     41.141333
# 209568      209569      1  38705I90583     132.000000   5911.533333
# 209569      209570      1  61602I90584    1298.000000  10800.000000
# 209570      209571      1  59960I88659     221.000000   4500.000000
# 209571      209572      0  59768I84453     827.000000   1867.668667
# 209572      209573      1  37836I89232     166.000000  13503.197333
# 209573      209574      1  02497I89237     642.000000  25235.000000
# 209574      209575      1  34697I70379     547.000000      9.509000
# 209575      209576      1  23627I70370     800.000000  26581.000000
# 209576      209577      1  70448I82734  811881.372822    149.760000
# 209577      209578      1  60261I84455    1007.000000   5079.832000
# 209578      209579      1  83229I89230    1256.000000  30900.830000
# 209579      209580      1  50019I70371     155.000000  11400.000000
# 209580      209581      1  13819I82733    1365.000000  18657.000000
# 209581      209582      1  39326I91197     377.000000  28785.000000
# 209582      209583      1  36726I95205      93.000000   1062.400000
# 209583      209584      1  30201I82732     935.000000     15.550667
# 209584      209585      0  70387I89237     945.000000      0.000000
# 209585      209586      1  12227I90843     793.000000   5350.315333
# 209586      209587      1  60331I70370     254.000000  20079.157333
# 209587      209588      1  19900I95200     239.000000  14678.000000
# 209588      209589      1  22758I85348     404.000000    151.872333
# 209589      209590      1  95583I84455    1075.000000     36.936000
# 209590      209591      1  28556I85350    1013.000000  11843.111667
# 209591      209592      1  59712I82733    1732.000000  12488.228333
# 209592      209593      1  65061I85339    1581.000000   4489.362000
#
#         daily_decr90  rental30  rental90  last_rech_date_ma  \
# 0        3065.150000    220.13    260.13                2.0
# 1       12124.750000   3691.26   3691.26               20.0
# 2        1398.000000    900.13    900.13                3.0
# 3          21.228000    159.42    159.42               41.0
# 4         150.619333   1098.90   1098.90                4.0
# 5        2261.460000    368.13    380.13                2.0
# 6        2883.970000    335.75    402.90               13.0
# 7       17804.150000    900.35   2549.11                4.0
# 8          90.695000   2287.50   2287.50                1.0
# 9          29.357333    612.96    612.96               11.0
# 10         12.896000    790.44    790.44                8.0
# 11         65.166667    326.20    326.20               17.0
# 12        227.041000    240.41    240.41                2.0
# 13         55.909333    208.80    208.80                2.0
# 14      10317.350000    399.25   2453.78                3.0
# 15         12.000000   1216.80   1216.80                0.0
# 16       1000.000000   1000.80   1087.88                0.0
# 17         10.688000     40.00     40.00                0.0
# 18         14.400000   1660.96   1660.96                1.0
# 19         48.935000    726.30    726.30                1.0
# 20        777.460000   1050.57   1167.30                6.0
# 21        515.200000     56.26     58.20                2.0
# 22       1541.000000    969.12    969.12                4.0
# 23         58.023333    479.44    479.44                2.0
# 24        291.563333  -2020.09  -2020.09                0.0
# 25         63.250000   2855.70   2855.70                1.0
# 26       3712.840000    340.96    376.42                2.0
# 27        508.000000   9276.68  10569.17               16.0
# 28       6705.260000   3553.83   3653.05                1.0
# 29         16.166667    962.60    962.60                3.0
# ...              ...       ...       ...                ...
# 209563     74.700000    752.94    752.94               11.0
# 209564   8186.540000   5007.66   5264.70                1.0
# 209565     33.788333     74.48     74.48                6.0
# 209566     48.555000    132.47    132.47               16.0
# 209567     41.141333   1881.23   1881.23                6.0
# 209568   5911.533333   1902.27   1902.27                5.0
# 209569  13445.000000   3638.99   4248.42                9.0
# 209570   8230.400000    934.60   3185.09                8.0
# 209571   1881.180000   1875.72   2312.65               14.0
# 209572  13561.960000    853.69   1299.73               21.0
# 209573  25347.750000  14948.51  24240.28                1.0
# 209574      9.509000    -16.86    -16.86                0.0
# 209575  28916.390000   4191.48   6785.92                1.0
# 209576    149.760000    922.20    922.20                4.0
# 209577   5104.540000   2844.84   3064.68                2.0
# 209578  45485.280000   8438.77  14562.40                5.0
# 209579  16265.000000   3611.23   7196.49                3.0
# 209580  24825.000000   6314.34  12318.22               26.0
# 209581  45515.000000   3956.57  14753.13                2.0
# 209582   1065.500000    248.13    260.13                1.0
# 209583     15.550667    140.44    140.44                4.0
# 209584      0.000000     78.30     78.30                0.0
# 209585   5356.210000    594.80    640.20                2.0
# 209586  20228.090000   4003.12   5173.74                2.0
# 209587  14704.900000  12935.26  16775.60                8.0
# 209588    151.872333   1089.19   1089.19                1.0
# 209589     36.936000   1728.36   1728.36                4.0
# 209590  11904.350000   5861.83   8893.20                3.0
# 209591  12574.370000    411.83    984.58                2.0
# 209592   4534.820000    483.92    631.20               13.0
#
#         last_rech_date_da  ...  maxamnt_loans30  medianamnt_loans30  \
# 0                     0.0  ...              6.0                 0.0
# 1                     0.0  ...             12.0                 0.0
# 2                     0.0  ...              6.0                 0.0
# 3                     0.0  ...              6.0                 0.0
# 4                     0.0  ...              6.0                 0.0
# 5                     0.0  ...              6.0                 0.0
# 6                     0.0  ...              6.0                 0.0
# 7                    55.0  ...              6.0                 0.0
# 8                     0.0  ...              6.0                 0.0
# 9                     0.0  ...              6.0                 0.0
# 10                    0.0  ...              6.0                 0.0
# 11                    0.0  ...              6.0                 0.0
# 12                    0.0  ...              6.0                 0.0
# 13                    0.0  ...              6.0                 0.0
# 14                    0.0  ...              6.0                 0.0
# 15                    0.0  ...              6.0                 0.0
# 16                    0.0  ...              6.0                 0.0
# 17                    0.0  ...              6.0                 0.0
# 18                    0.0  ...              6.0                 0.0
# 19                    0.0  ...              6.0                 0.0
# 20                    0.0  ...              6.0                 0.0
# 21                    0.0  ...              6.0                 0.0
# 22                    0.0  ...              6.0                 0.0
# 23                    0.0  ...              6.0                 0.0
# 24                    0.0  ...              6.0                 0.0
# 25                    0.0  ...              6.0                 0.0
# 26                    0.0  ...              6.0                 0.0
# 27                    0.0  ...              6.0                 0.0
# 28                    0.0  ...              6.0                 0.0
# 29                    0.0  ...              6.0                 0.0
# ...                   ...  ...              ...                 ...
# 209563                0.0  ...              6.0                 0.0
# 209564                0.0  ...              6.0                 0.0
# 209565                0.0  ...              6.0                 1.0
# 209566                0.0  ...              6.0                 0.0
# 209567                0.0  ...              6.0                 0.0
# 209568               17.0  ...              6.0                 0.0
# 209569                0.0  ...              6.0                 0.0
# 209570                0.0  ...              6.0                 0.0
# 209571                0.0  ...              6.0                 0.0
# 209572                0.0  ...              6.0                 0.0
# 209573                0.0  ...             12.0                 0.0
# 209574                0.0  ...              6.0                 0.0
# 209575                0.0  ...              6.0                 0.0
# 209576                0.0  ...              6.0                 0.0
# 209577                0.0  ...              6.0                 0.0
# 209578                0.0  ...             12.0                 0.0
# 209579                0.0  ...              6.0                 0.0
# 209580                0.0  ...              0.0                 0.0
# 209581                0.0  ...             12.0                 0.0
# 209582                0.0  ...              6.0                 0.0
# 209583                0.0  ...              6.0                 0.0
# 209584                0.0  ...              6.0                 0.0
# 209585                0.0  ...              6.0                 0.0
# 209586                0.0  ...             12.0                 0.0
# 209587                0.0  ...             12.0                 1.0
# 209588                0.0  ...              6.0                 0.0
# 209589                0.0  ...              6.0                 0.0
# 209590                0.0  ...             12.0                 0.0
# 209591               38.0  ...             12.0                 0.0
# 209592                0.0  ...             12.0                 0.0
#
#         cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# 0               2.0            12                6                 0.0
# 1               1.0            12               12                 0.0
# 2               1.0             6                6                 0.0
# 3               2.0            12                6                 0.0
# 4               7.0            42                6                 0.0
# 5               3.0            18                6                 0.0
# 6               1.0             6                6                 0.0
# 7               7.0            42                6                 0.0
# 8               4.0            24                6                 0.0
# 9               1.0             6                6                 0.0
# 10              2.0            12                6                 0.0
# 11              1.0             6                6                 0.0
# 12              4.0            24                6                 0.0
# 13              5.0            30                6                 0.0
# 14              7.0            42                6                 0.0
# 15              1.0             6                6                 0.0
# 16              1.0             6                6                 0.0
# 17              1.0             6                6                 0.0
# 18              1.0             6                6                 0.0
# 19              2.0            12                6                 0.0
# 20              1.0             6                6                 0.0
# 21              2.0            12                6                 0.0
# 22              2.0            12                6                 0.0
# 23              4.0            24                6                 0.0
# 24              1.0             6                6                 0.0
# 25              5.0            30                6                 0.0
# 26              5.0            30                6                 0.0
# 27              1.0             6                6                 0.0
# 28              8.0            48                6                 0.0
# 29              1.0             6                6                 0.0
# ...             ...           ...              ...                 ...
# 209563          1.0             6                6                 0.0
# 209564          5.0            30                6                 0.0
# 209565          1.0             6                6                 1.0
# 209566          1.0             6                6                 0.0
# 209567          2.0            12                6                 0.0
# 209568          4.0            24                6                 0.0
# 209569          6.0            36                6                 0.0
# 209570          5.0            30                6                 0.0
# 209571          1.0             6                6                 0.0
# 209572          2.0            12                6                 0.0
# 209573         12.0            90               12                 0.0
# 209574          1.0             6                6                 0.0
# 209575          3.0            18                6                 0.0
# 209576          2.0            12                6                 0.0
# 209577          6.0            36                6                 0.0
# 209578          6.0            48               12                 0.0
# 209579          7.0            42                6                 0.0
# 209580          0.0             0                0                 0.0
# 209581         10.0            72               12                 0.0
# 209582          1.0             6                6                 0.0
# 209583          1.0             6                6                 0.0
# 209584          1.0             6                6                 0.0
# 209585          5.0            30                6                 0.0
# 209586         15.0           120               12                 0.0
# 209587          3.0            24               12                 1.0
# 209588          2.0            12                6                 0.0
# 209589          3.0            18                6                 0.0
# 209590          6.0            54               12                 0.0
# 209591          3.0            24               12                 0.0
# 209592          2.0            18               12                 0.0
#
#         payback30  payback90  pcircle       pdate
# 0       29.000000  29.000000      UPW  2016-07-20
# 1        0.000000   0.000000      UPW  2016-08-10
# 2        0.000000   0.000000      UPW  2016-08-19
# 3        0.000000   0.000000      UPW  2016-06-06
# 4        2.333333   2.333333      UPW  2016-06-22
# 5       11.000000   8.333333      UPW  2016-07-02
# 6        0.000000   0.000000      UPW  2016-07-05
# 7        6.000000   3.857143      UPW  2016-08-05
# 8        2.666667   2.666667      UPW  2016-06-15
# 9        0.000000   0.000000      UPW  2016-06-08
# 10       4.000000   4.000000      UPW  2016-06-12
# 11       0.000000   0.000000      UPW  2016-06-20
# 12       1.333333   1.333333      UPW  2016-06-29
# 13       2.600000   2.600000      UPW  2016-06-16
# 14       5.000000   4.166667      UPW  2016-08-03
# 15       0.000000   0.000000      UPW  2016-06-24
# 16       0.000000   0.000000      UPW  2016-07-04
# 17       0.000000   0.000000      UPW  2016-06-16
# 18       0.000000   0.000000      UPW  2016-06-08
# 19       5.000000   5.000000      UPW  2016-06-15
# 20       0.000000   0.000000      UPW  2016-07-03
# 21       0.000000   0.000000      UPW  2016-07-01
# 22       0.000000  42.000000      UPW  2016-08-08
# 23       6.000000   6.000000      UPW  2016-06-26
# 24       0.000000   0.000000      UPW  2016-06-23
# 25       1.800000   1.800000      UPW  2016-06-15
# 26       6.000000   6.000000      UPW  2016-07-06
# 27       0.000000   0.000000      UPW  2016-07-09
# 28       1.375000   1.666667      UPW  2016-07-02
# 29       0.000000   0.000000      UPW  2016-06-10
# ...           ...        ...      ...         ...
# 209563   0.000000   0.000000      UPW  2016-06-18
# 209564   2.000000   1.800000      UPW  2016-07-17
# 209565   0.000000   0.000000      UPW  2016-06-19
# 209566   0.000000   0.000000      UPW  2016-06-13
# 209567   0.000000   0.000000      UPW  2016-06-29
# 209568   3.333333   3.333333      UPW  2016-07-23
# 209569   4.666667   5.428571      UPW  2016-08-05
# 209570  11.500000   7.400000      UPW  2016-08-09
# 209571   0.000000   0.000000      UPW  2016-07-13
# 209572   0.000000   0.000000      UPW  2016-07-28
# 209573   5.615385   6.357143      UPW  2016-08-15
# 209574   0.000000   0.000000      UPW  2016-06-03
# 209575   1.000000   6.000000      UPW  2016-08-13
# 209576   5.500000   5.500000      UPW  2016-06-15
# 209577   1.600000   1.600000      UPW  2016-07-06
# 209578   3.250000   3.800000      UPW  2016-08-15
# 209579   6.000000   6.142857      UPW  2016-08-14
# 209580   0.000000   0.000000      UPW  2016-08-06
# 209581   2.666667   2.777778      UPW  2016-08-16
# 209582   0.000000   0.000000      UPW  2016-07-06
# 209583   0.000000   0.000000      UPW  2016-06-02
# 209584   0.000000   0.000000      UPW  2016-06-06
# 209585   5.200000   5.200000      UPW  2016-07-04
# 209586   3.000000   2.400000      UPW  2016-07-22
# 209587   0.000000  30.000000      UPW  2016-08-02
# 209588   1.000000   1.000000      UPW  2016-06-17
# 209589   1.000000   1.000000      UPW  2016-06-12
# 209590   4.000000   3.833333      UPW  2016-07-29
# 209591   0.000000  10.500000      UPW  2016-07-25
# 209592   0.000000   0.000000      UPW  2016-07-07
#
# [209593 rows x 37 columns]

# %% [markdown]
# The dataset consists of 209593 records and 37 attributes in the dataset initially.
#
# We can see an "Unnamed: 0" column acting as an index in the dataset which does not serve as any information to the data. Hence, we drop the column.
#
# We can see another variable "msisdn" with big values which are the mobile numbers of the users and does not have any relevance with the data analysis. Hence, we will treat this column as an index.

# %%
#Initial variables in the dataset (before data cleaning)
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
#Dropping "Unnamed: 0" column from the dataset
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
#Setting "msisdn" as index
df.set_index("msisdn",inplace=True)
#Visualizing first 5 columns of dataset
df.head()
# Out:
#              label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# msisdn
# 21408I70789      0  272.0   3055.050000   3065.150000    220.13    260.13
# 76462I70374      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 17943I70372      1  535.0   1398.000000   1398.000000    900.13    900.13
# 55773I70781      1  241.0     21.228000     21.228000    159.42    159.42
# 03813I82730      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#              last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# msisdn
# 21408I70789                2.0                0.0              1539
# 76462I70374               20.0                0.0              5787
# 17943I70372                3.0                0.0              1539
# 55773I70781               41.0                0.0               947
# 03813I82730                4.0                0.0              2309
#
#              cnt_ma_rech30  ...  maxamnt_loans30  medianamnt_loans30  \
# msisdn                      ...
# 21408I70789              2  ...              6.0                 0.0
# 76462I70374              1  ...             12.0                 0.0
# 17943I70372              1  ...              6.0                 0.0
# 55773I70781              0  ...              6.0                 0.0
# 03813I82730              7  ...              6.0                 0.0
#
#              cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# msisdn
# 21408I70789          2.0            12                6                 0.0
# 76462I70374          1.0            12               12                 0.0
# 17943I70372          1.0             6                6                 0.0
# 55773I70781          2.0            12                6                 0.0
# 03813I82730          7.0            42                6                 0.0
#
#              payback30  payback90  pcircle       pdate
# msisdn
# 21408I70789  29.000000  29.000000      UPW  2016-07-20
# 76462I70374   0.000000   0.000000      UPW  2016-08-10
# 17943I70372   0.000000   0.000000      UPW  2016-08-19
# 55773I70781   0.000000   0.000000      UPW  2016-06-06
# 03813I82730   2.333333   2.333333      UPW  2016-06-22
#
# [5 rows x 35 columns]

# %% [markdown]
# Hence, we can notice that the variable "Unnamed: 0" has been dropped and column "msisdn" is featuring like an index in the dataset.
#
# As we can see we have lots of columns present in the dataset but cannot see all of them in the above dataframe, we will try to visualize the maximum attributes possible.

# %%
#Splitting variable "pdate" into pday, pmonth and pyear
df["pyear"]=df["pdate"].str.split("-").str[0]
df["pmonth"]=df["pdate"].str.split("-").str[1]
df["pdate"]=df["pdate"].str.split("-").str[2]

# %%
#Displaying data to verify the splitted data
df.head()
# Out:
#              label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# msisdn
# 21408I70789      0  272.0   3055.050000   3065.150000    220.13    260.13
# 76462I70374      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 17943I70372      1  535.0   1398.000000   1398.000000    900.13    900.13
# 55773I70781      1  241.0     21.228000     21.228000    159.42    159.42
# 03813I82730      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#              last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# msisdn
# 21408I70789                2.0                0.0              1539
# 76462I70374               20.0                0.0              5787
# 17943I70372                3.0                0.0              1539
# 55773I70781               41.0                0.0               947
# 03813I82730                4.0                0.0              2309
#
#              cnt_ma_rech30  ...  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# msisdn                      ...
# 21408I70789              2  ...          2.0            12                6
# 76462I70374              1  ...          1.0            12               12
# 17943I70372              1  ...          1.0             6                6
# 55773I70781              0  ...          2.0            12                6
# 03813I82730              7  ...          7.0            42                6
#
#              medianamnt_loans90  payback30  payback90  pcircle  pdate  pyear  \
# msisdn
# 21408I70789                 0.0  29.000000  29.000000      UPW     20   2016
# 76462I70374                 0.0   0.000000   0.000000      UPW     10   2016
# 17943I70372                 0.0   0.000000   0.000000      UPW     19   2016
# 55773I70781                 0.0   0.000000   0.000000      UPW     06   2016
# 03813I82730                 0.0   2.333333   2.333333      UPW     22   2016
#
#              pmonth
# msisdn
# 21408I70789      07
# 76462I70374      08
# 17943I70372      08
# 55773I70781      06
# 03813I82730      06
#
# [5 rows x 37 columns]

# %% [markdown]
# Variable "pdate" is now splitted into three columns of pdate, pmonth and pyear.

# %%
#Checking size of present dataset
df.shape
# Out:
# (209593, 37)

# %% [markdown]
# The dataset now consits of 37 columns.

# %%
#Checking data types of the new attributes creates
df.dtypes
# Out:
# label                     int64
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# maxamnt_loans90           int64
# medianamnt_loans90      float64
# payback30               float64
# payback90               float64
# pcircle                  object
# pdate                    object
# pyear                    object
# pmonth                   object
# dtype: object

# %% [markdown]
# The data types of pdate, pyear and pmonth is showing as object datatype. Hence, we will convert it to an integer type of data.

# %%
#Converting object variables into integer type
df["pyear"]=df["pyear"].astype(int)
df["pmonth"]=df["pmonth"].astype(int)
df["pdate"]=df["pdate"].astype(int)

# %%
#Verifying data types of retrieved data
df.dtypes
# Out:
# label                     int64
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# maxamnt_loans90           int64
# medianamnt_loans90      float64
# payback30               float64
# payback90               float64
# pcircle                  object
# pdate                     int32
# pyear                     int32
# pmonth                    int32
# dtype: object

# %% [markdown]
# The data types of variables pdate, pyear and pmonth is now of the integer type. Only attribute "pcircle" is of the object datatype, hence we will convert these string values into integer numbers using the Label Encoder Encoding technique.

# %% [markdown]
# # Data Encoding

# %%
#Importing library for label encoding 
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
#Creating an object for label encoder and applying it on the column
le=LabelEncoder()
df['pcircle']=le.fit_transform(df['pcircle'])

# %%
#Creating an object for label encoder and applying it on the column
le=LabelEncoder()
df['pcircle']=le.fit_transform(df['pcircle'])

# %%
#Verifying encoded column
df.head()
# Out:
#              label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# msisdn
# 21408I70789      0  272.0   3055.050000   3065.150000    220.13    260.13
# 76462I70374      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 17943I70372      1  535.0   1398.000000   1398.000000    900.13    900.13
# 55773I70781      1  241.0     21.228000     21.228000    159.42    159.42
# 03813I82730      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#              last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# msisdn
# 21408I70789                2.0                0.0              1539
# 76462I70374               20.0                0.0              5787
# 17943I70372                3.0                0.0              1539
# 55773I70781               41.0                0.0               947
# 03813I82730                4.0                0.0              2309
#
#              cnt_ma_rech30  ...  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# msisdn                      ...
# 21408I70789              2  ...          2.0            12                6
# 76462I70374              1  ...          1.0            12               12
# 17943I70372              1  ...          1.0             6                6
# 55773I70781              0  ...          2.0            12                6
# 03813I82730              7  ...          7.0            42                6
#
#              medianamnt_loans90  payback30  payback90  pcircle  pdate  pyear  \
# msisdn
# 21408I70789                 0.0  29.000000  29.000000        0     20   2016
# 76462I70374                 0.0   0.000000   0.000000        0     10   2016
# 17943I70372                 0.0   0.000000   0.000000        0     19   2016
# 55773I70781                 0.0   0.000000   0.000000        0      6   2016
# 03813I82730                 0.0   2.333333   2.333333        0     22   2016
#
#              pmonth
# msisdn
# 21408I70789       7
# 76462I70374       8
# 17943I70372       8
# 55773I70781       6
# 03813I82730       6
#
# [5 rows x 37 columns]

# %% [markdown]
# Attribute "pcircle" has been converted into numeric form of data.

# %% [markdown]
# # Checking Null Values

# %%
#Checking Null values
df.isnull().sum()
# Out:
# label                   0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# pdate                   0
# pyear                   0
# pmonth                  0
# dtype: int64

# %% [markdown]
# There are no Null Values in the dataset. Hence, we can proceed forward with visualizing data.

# %% [markdown]
# # Data Visualization

# %%
#Importing Libraries for Visualization
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Using countplot for nominal type of data

# %%
ab=sns.countplot(x='label', data=df)
print(df['label'].value_counts())
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# 183431 customers paid back the credit amount(loan) within 5 days of issuing the loan i.e. they are non-defaulters and 26162 customers did not pay back the loan within 5 days of issuing the loan which means they are defaulters. Approximately 87.5% customers are non defaulters and only 12.5% customers are defaulters from the above graph.

# %%
ab=sns.countplot(x='pcircle', data=df)
print(df['pcircle'].value_counts())
# Out:
# 0    209593
# Name: pcircle, dtype: int64

# %% [markdown]
# The telecom circle of all the customers is UPW i.e. single value for all the records which makes no difference in the analysis of data. Hence, we drop the column.

# %%
ab=sns.countplot(x='pyear', data=df)
print(df['pyear'].value_counts())
# Out:
# 2016    209593
# Name: pyear, dtype: int64

# %% [markdown]
# The whole record consists of the year 2016 which does not serve as an important information for analyzing data. Hence, we drop the variable.

# %%
ab=sns.countplot(x='medianamnt_loans90', data=df)
print(df['medianamnt_loans90'].value_counts())
# Out:
# 0.0    197424
# 1.0      6172
# 0.5      5668
# 2.0       307
# 1.5        19
# 3.0         3
# Name: medianamnt_loans90, dtype: int64

# %% [markdown]
# Median of amounts of loan taken by the user in last 90 days is 0.0 for 197424 customers which is for the maximum records and 3.0 for 3 customers which is the minimum records.

# %%
ab=sns.countplot(x='maxamnt_loans90', data=df)
print(df['maxamnt_loans90'].value_counts())
# Out:
# 6     180945
# 12     26605
# 0       2043
# Name: maxamnt_loans90, dtype: int64

# %% [markdown]
# Maximum amount of loan taken by the user in last 90 days is 6 for 180945 customers (maximum records), 12 for 26605 customers and 0 for 2043 customers (minimum records)

# %%
ab=sns.countplot(x='medianamnt_loans30', data=df)
print(df['medianamnt_loans30'].value_counts())
# Out:
# 0.0    195445
# 1.0      7149
# 0.5      6538
# 2.0       420
# 1.5        38
# 3.0         3
# Name: medianamnt_loans30, dtype: int64

# %% [markdown]
# Median of amounts of loan taken by the user in last 30 days is 0.0 for 195445 customers which is for the maximum records and 3.0 for 3 customers which is the minimum records.

# %%
ab=sns.countplot(x='pmonth', data=df)
print(df['pmonth'].value_counts())
# Out:
# 7    85765
# 6    83154
# 8    40674
# Name: pmonth, dtype: int64

# %% [markdown]
# Maximum records are from the month of July(7) i.e. 85765 records, 83154 records from the month of June and 40674 records from the month of August which is the least.

# %%
#Dropping the columns which are not important
df.drop(['pyear','pcircle'],axis=1,inplace=True)

# %%
#Verifying dropped columns
df.head()
# Out:
#              label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# msisdn
# 21408I70789      0  272.0   3055.050000   3065.150000    220.13    260.13
# 76462I70374      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 17943I70372      1  535.0   1398.000000   1398.000000    900.13    900.13
# 55773I70781      1  241.0     21.228000     21.228000    159.42    159.42
# 03813I82730      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#              last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# msisdn
# 21408I70789                2.0                0.0              1539
# 76462I70374               20.0                0.0              5787
# 17943I70372                3.0                0.0              1539
# 55773I70781               41.0                0.0               947
# 03813I82730                4.0                0.0              2309
#
#              cnt_ma_rech30  ...  maxamnt_loans30  medianamnt_loans30  \
# msisdn                      ...
# 21408I70789              2  ...              6.0                 0.0
# 76462I70374              1  ...             12.0                 0.0
# 17943I70372              1  ...              6.0                 0.0
# 55773I70781              0  ...              6.0                 0.0
# 03813I82730              7  ...              6.0                 0.0
#
#              cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# msisdn
# 21408I70789          2.0            12                6                 0.0
# 76462I70374          1.0            12               12                 0.0
# 17943I70372          1.0             6                6                 0.0
# 55773I70781          2.0            12                6                 0.0
# 03813I82730          7.0            42                6                 0.0
#
#              payback30  payback90  pdate  pmonth
# msisdn
# 21408I70789  29.000000  29.000000     20       7
# 76462I70374   0.000000   0.000000     10       8
# 17943I70372   0.000000   0.000000     19       8
# 55773I70781   0.000000   0.000000      6       6
# 03813I82730   2.333333   2.333333     22       6
#
# [5 rows x 35 columns]

# %% [markdown]
# Variables "pcircle" and "pyear" cannot be seen in the above dataset

# %% [markdown]
# # Making DataFrame of the Continuous type of Values

# %%
#Creatig a new dataframe
df1=df[['aon','daily_decr30', 'daily_decr90', 'rental30', 'rental90','last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma','cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30','medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90','fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90','medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30','cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30','maxamnt_loans30', 'cnt_loans90', 'amnt_loans90','payback30','payback90','pdate']].copy()

# %%
#Visualizing different columns using distplot
ncol,nrow=10,4
ab=df1.columns.values
plt.figure(figsize=(20,20))
for index,i in enumerate(ab):
    ab=plt.subplot(ncol,nrow,index+1)
    df[i].hist(grid=True)
    plt.title(f"plot {i}")
    plt.tight_layout()
plt.show()

# %% [markdown]
# Observations:
#
# There are more than 2000 records for the dates 1 to 18 of the month but the records for the dates 18 to 31 are less than 2000.
#
# Most of the values are observed to be 0 values in almost all the variables which indicates that there is no record history for most of the features.
#
# Frequency of main account recharged in last 90 days (fr_ma_rech90) lies between values 0 to 60.
#
# Number of loans taken by user in last 30 days (cnt_loans30) lies between values 0 to 30 but maximum records lie between 0 & 10.
#
# Total amount of loans taken by user in last 30 days (amnt_loans30) is between values 0 & 150 but maximum records lie between values 0 & 60.
#
# As there are too many variables present, hence it's difficult to analyze each attribute separately, hence we'll try to understand data using different visualization techniques.

# %% [markdown]
# # Describe Data

# %%
#Describing columns present in dataset
df.columns
# Out:
# Index(['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90',
#        'pdate', 'pmonth'],
#       dtype='object')

# %%
#Defining Shape
df.shape
# Out:
# (209593, 35)

# %%
#Getting data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209593 entries, 21408I70789 to 65061I85339
# Data columns (total 35 columns):
# label                   209593 non-null int64
# aon                     209593 non-null float64
# daily_decr30            209593 non-null float64
# daily_decr90            209593 non-null float64
# rental30                209593 non-null float64
# rental90                209593 non-null float64
# last_rech_date_ma       209593 non-null float64
# last_rech_date_da       209593 non-null float64
# last_rech_amt_ma        209593 non-null int64
# cnt_ma_rech30           209593 non-null int64
# fr_ma_rech30            209593 non-null float64
# sumamnt_ma_rech30       209593 non-null float64
# medianamnt_ma_rech30    209593 non-null float64
# medianmarechprebal30    209593 non-null float64
# cnt_ma_rech90           209593 non-null int64
# fr_ma_rech90            209593 non-null int64
# sumamnt_ma_rech90       209593 non-null int64
# medianamnt_ma_rech90    209593 non-null float64
# medianmarechprebal90    209593 non-null float64
# cnt_da_rech30           209593 non-null float64
# fr_da_rech30            209593 non-null float64
# cnt_da_rech90           209593 non-null int64
# fr_da_rech90            209593 non-null int64
# cnt_loans30             209593 non-null int64
# amnt_loans30            209593 non-null int64
# maxamnt_loans30         209593 non-null float64
# medianamnt_loans30      209593 non-null float64
# cnt_loans90             209593 non-null float64
# amnt_loans90            209593 non-null int64
# maxamnt_loans90         209593 non-null int64
# medianamnt_loans90      209593 non-null float64
# payback30               209593 non-null float64
# payback90               209593 non-null float64
# pdate                   209593 non-null int32
# pmonth                  209593 non-null int32
# dtypes: float64(21), int32(2), int64(12)
# memory usage: 61.0+ MB

# %% [markdown]
# We have no Null Values and all values in the dataset are in int/float values. Now, we can proceed forward with describing and understanding data.

# %%
#Describing mean, median, min, max values of data
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# 25%       280.420000     300.260000           1.000000           0.000000
# 50%      1083.570000    1334.000000           3.000000           0.000000
# 75%      3356.940000    4201.790000           7.000000           0.000000
# max    198926.110000  200148.110000      998650.377733      999171.809410
#
#        last_rech_amt_ma  cnt_ma_rech30  ...  maxamnt_loans30  \
# count     209593.000000  209593.000000  ...    209593.000000
# mean        2064.452797       3.978057  ...       274.658747
# std         2370.786034       4.256090  ...      4245.264648
# min            0.000000       0.000000  ...         0.000000
# 25%          770.000000       1.000000  ...         6.000000
# 50%         1539.000000       3.000000  ...         6.000000
# 75%         2309.000000       5.000000  ...         6.000000
# max        55000.000000     203.000000  ...     99864.560864
#
#        medianamnt_loans30    cnt_loans90   amnt_loans90  maxamnt_loans90  \
# count       209593.000000  209593.000000  209593.000000    209593.000000
# mean             0.054029      18.520919      23.645398         6.703134
# std              0.218039     224.797423      26.469861         2.103864
# min              0.000000       0.000000       0.000000         0.000000
# 25%              0.000000       1.000000       6.000000         6.000000
# 50%              0.000000       2.000000      12.000000         6.000000
# 75%              0.000000       5.000000      30.000000         6.000000
# max              3.000000    4997.517944     438.000000        12.000000
#
#        medianamnt_loans90      payback30      payback90         pdate  \
# count       209593.000000  209593.000000  209593.000000  209593.00000
# mean             0.046077       3.398826       4.321485      14.39894
# std              0.200692       8.813729      10.308108       8.43890
# min              0.000000       0.000000       0.000000       1.00000
# 25%              0.000000       0.000000       0.000000       7.00000
# 50%              0.000000       0.000000       1.666667      14.00000
# 75%              0.000000       3.750000       4.500000      21.00000
# max              3.000000     171.500000     171.500000      31.00000
#
#               pmonth
# count  209593.000000
# mean        6.797321
# std         0.741435
# min         6.000000
# 25%         6.000000
# 50%         7.000000
# 75%         7.000000
# max         8.000000
#
# [8 rows x 35 columns]

# %%
#Visualizing data description
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor='blue',fmt='0.2f')

# %% [markdown]
# Observation:
#
# The standard deviation of the columns in our dataset is very huge which means that the values in these columns are largely scattered and are not near to the mean values. They are very far away from their mean values.
#
# The values in some attributes like 'aon','daily_decr30','daily_decr90','rental30','rental90','last_rech_date_ma','last_rech_date_da','medianmarechprebal30'and 'medianmarechprebal90' ranges from negative values to high positive values. The value range inside each attribute is very high within the dataset.
#
# The min & max values in every column has huge range difference which indicates a possibility of having outliers and skewness in data.
#
# Variables 'aon','last_rech_date_ma','last_rech_date_da','fr_ma_rech30','medianmarechprebal30','sumamnt_ma_rech90' and 'fr_da_rech30' have got the highest range of values reaching 1000000.

# %% [markdown]
# # Correlation of Columns with the Target Variable

# %%
#Checking correlation between variables
df.corr()
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.003785      0.168298      0.166150
# aon                  -0.003785  1.000000      0.001104      0.000374
# daily_decr30          0.168298  0.001104      1.000000      0.977704
# daily_decr90          0.166150  0.000374      0.977704      1.000000
# rental30              0.058085 -0.000960      0.442066      0.434685
# rental90              0.075521 -0.000790      0.458977      0.471730
# last_rech_date_ma     0.003728  0.001692      0.000487      0.000908
# last_rech_date_da     0.001711 -0.001693     -0.001636     -0.001886
# last_rech_amt_ma      0.131804  0.004256      0.275837      0.264131
# cnt_ma_rech30         0.237331 -0.003148      0.451385      0.426707
# fr_ma_rech30          0.001330 -0.001163     -0.000577     -0.000343
# sumamnt_ma_rech30     0.202828  0.000707      0.636536      0.603886
# medianamnt_ma_rech30  0.141490  0.004306      0.295356      0.282960
# medianmarechprebal30 -0.004829  0.003930     -0.001153     -0.000746
# cnt_ma_rech90         0.236392 -0.002725      0.587338      0.593069
# fr_ma_rech90          0.084385  0.004401     -0.078299     -0.079530
# sumamnt_ma_rech90     0.205793  0.001011      0.762981      0.768817
# medianamnt_ma_rech90  0.120855  0.004909      0.257847      0.250518
# medianmarechprebal90  0.039300 -0.000859      0.037495      0.036382
# cnt_da_rech30         0.003827  0.001564      0.000700      0.000661
# fr_da_rech30         -0.000027  0.000892     -0.001499     -0.001570
# cnt_da_rech90         0.002999  0.001121      0.038814      0.031155
# fr_da_rech90         -0.005418  0.005395      0.020673      0.016437
# cnt_loans30           0.196283 -0.001826      0.366116      0.340387
# amnt_loans30          0.197272 -0.001726      0.471492      0.447869
# maxamnt_loans30       0.000248 -0.002764     -0.000028      0.000025
# medianamnt_loans30    0.044589  0.004664     -0.011610     -0.005591
# cnt_loans90           0.004733 -0.000611      0.008962      0.009446
# amnt_loans90          0.199788 -0.002319      0.563496      0.567204
# maxamnt_loans90       0.084144 -0.001191      0.400199      0.397251
# medianamnt_loans90    0.035747  0.002771     -0.037305     -0.034686
# payback30             0.048336  0.001940      0.026915      0.019400
# payback90             0.049183  0.002203      0.047175      0.040800
# pdate                 0.006825  0.000662      0.006477     -0.021508
# pmonth                0.154949 -0.001863      0.518664      0.539410
#
#                       rental30  rental90  last_rech_date_ma  \
# label                 0.058085  0.075521           0.003728
# aon                  -0.000960 -0.000790           0.001692
# daily_decr30          0.442066  0.458977           0.000487
# daily_decr90          0.434685  0.471730           0.000908
# rental30              1.000000  0.955237          -0.001095
# rental90              0.955237  1.000000          -0.001688
# last_rech_date_ma    -0.001095 -0.001688           1.000000
# last_rech_date_da     0.003261  0.002794           0.001790
# last_rech_amt_ma      0.127271  0.121416          -0.000147
# cnt_ma_rech30         0.233343  0.230260           0.004311
# fr_ma_rech30         -0.001219 -0.000503          -0.001629
# sumamnt_ma_rech30     0.272649  0.259709           0.002105
# medianamnt_ma_rech30  0.129853  0.120242          -0.001358
# medianmarechprebal30 -0.001415 -0.001237           0.004071
# cnt_ma_rech90         0.312118  0.345293           0.004263
# fr_ma_rech90         -0.033530 -0.036524           0.001414
# sumamnt_ma_rech90     0.342306  0.360601           0.002243
# medianamnt_ma_rech90  0.110356  0.103151          -0.000726
# medianmarechprebal90  0.027170  0.029547          -0.001086
# cnt_da_rech30        -0.001105 -0.000548          -0.003467
# fr_da_rech30         -0.002558 -0.002345          -0.003626
# cnt_da_rech90         0.072255  0.056282          -0.003538
# fr_da_rech90          0.046761  0.036886          -0.002395
# cnt_loans30           0.180203  0.171595           0.001193
# amnt_loans30          0.233453  0.231906           0.000903
# maxamnt_loans30      -0.000864 -0.001411           0.000928
# medianamnt_loans30   -0.016482 -0.009467           0.001835
# cnt_loans90           0.004012  0.005141          -0.000225
# amnt_loans90          0.298943  0.327436           0.000870
# maxamnt_loans90       0.234211  0.251029          -0.001123
# medianamnt_loans90   -0.035489 -0.034122           0.002771
# payback30             0.072974  0.067110          -0.002233
# payback90             0.095147  0.099501          -0.001583
# pdate                 0.036537  0.008941           0.000560
# pmonth                0.365699  0.429407          -0.001207
#
#                       last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  ...  \
# label                          0.001711          0.131804       0.237331  ...
# aon                           -0.001693          0.004256      -0.003148  ...
# daily_decr30                  -0.001636          0.275837       0.451385  ...
# daily_decr90                  -0.001886          0.264131       0.426707  ...
# rental30                       0.003261          0.127271       0.233343  ...
# rental90                       0.002794          0.121416       0.230260  ...
# last_rech_date_ma              0.001790         -0.000147       0.004311  ...
# last_rech_date_da              1.000000         -0.000149       0.001549  ...
# last_rech_amt_ma              -0.000149          1.000000      -0.002662  ...
# cnt_ma_rech30                  0.001549         -0.002662       1.000000  ...
# fr_ma_rech30                   0.001158          0.002876       0.001669  ...
# sumamnt_ma_rech30              0.000046          0.440821       0.656986  ...
# medianamnt_ma_rech30           0.001037          0.794646      -0.011792  ...
# medianmarechprebal30           0.002849         -0.002342       0.000082  ...
# cnt_ma_rech90                  0.001272          0.016707       0.886433  ...
# fr_ma_rech90                   0.000798          0.106267      -0.152759  ...
# sumamnt_ma_rech90             -0.000414          0.418735       0.584060  ...
# medianamnt_ma_rech90           0.000219          0.818734      -0.051347  ...
# medianmarechprebal90           0.004158          0.124646       0.013463  ...
# cnt_da_rech30                 -0.003628         -0.001837       0.002306  ...
# fr_da_rech30                  -0.000074         -0.003230      -0.002732  ...
# cnt_da_rech90                 -0.001859          0.014779       0.011981  ...
# fr_da_rech90                  -0.000203          0.016042       0.006989  ...
# cnt_loans30                    0.000380         -0.027612       0.765802  ...
# amnt_loans30                   0.000536          0.008502       0.752296  ...
# maxamnt_loans30                0.000503          0.001000       0.000109  ...
# medianamnt_loans30             0.000061          0.028370      -0.067011  ...
# cnt_loans90                   -0.000972          0.000093       0.014703  ...
# amnt_loans90                   0.000519          0.014067       0.685257  ...
# maxamnt_loans90                0.001524          0.148460       0.174104  ...
# medianamnt_loans90            -0.002239          0.021004      -0.071451  ...
# payback30                      0.000077         -0.027369       0.043617  ...
# payback90                      0.000417         -0.014260       0.017362  ...
# pdate                          0.000631          0.028883       0.068643  ...
# pmonth                        -0.001800          0.096919       0.156148  ...
#
#                       maxamnt_loans30  medianamnt_loans30  cnt_loans90  \
# label                        0.000248            0.044589     0.004733
# aon                         -0.002764            0.004664    -0.000611
# daily_decr30                -0.000028           -0.011610     0.008962
# daily_decr90                 0.000025           -0.005591     0.009446
# rental30                    -0.000864           -0.016482     0.004012
# rental90                    -0.001411           -0.009467     0.005141
# last_rech_date_ma            0.000928            0.001835    -0.000225
# last_rech_date_da            0.000503            0.000061    -0.000972
# last_rech_amt_ma             0.001000            0.028370     0.000093
# cnt_ma_rech30                0.000109           -0.067011     0.014703
# fr_ma_rech30                -0.001100           -0.000331     0.003368
# sumamnt_ma_rech30            0.001633           -0.034460     0.009419
# medianamnt_ma_rech30         0.001985            0.032477    -0.001143
# medianmarechprebal30        -0.002176           -0.002289     0.001342
# cnt_ma_rech90               -0.000573           -0.053637     0.015754
# fr_ma_rech90                 0.001635            0.020626    -0.002756
# sumamnt_ma_rech90            0.001152           -0.022133     0.011306
# medianamnt_ma_rech90         0.001016            0.036475    -0.000123
# medianmarechprebal90         0.001884            0.030534    -0.000926
# cnt_da_rech30               -0.000394            0.000049    -0.001986
# fr_da_rech30                -0.001070           -0.001141    -0.001623
# cnt_da_rech90               -0.001855           -0.003351     0.000907
# fr_da_rech90                -0.000754           -0.002234     0.001993
# cnt_loans30                  0.000251           -0.093146     0.015595
# amnt_loans30                -0.000073           -0.078531     0.014625
# maxamnt_loans30              1.000000            0.007782     0.003987
# medianamnt_loans30           0.007782            1.000000    -0.003670
# cnt_loans90                  0.003987           -0.003670     1.000000
# amnt_loans90                -0.001850           -0.067580     0.017697
# maxamnt_loans90             -0.000487            0.058378     0.001450
# medianamnt_loans90           0.009330            0.911604    -0.002571
# payback30                   -0.001512           -0.006007     0.000587
# payback90                   -0.000915            0.003178    -0.000476
# pdate                        0.002531           -0.003479     0.001969
# pmonth                      -0.003801            0.048908     0.003577
#
#                       amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# label                     0.199788         0.084144            0.035747
# aon                      -0.002319        -0.001191            0.002771
# daily_decr30              0.563496         0.400199           -0.037305
# daily_decr90              0.567204         0.397251           -0.034686
# rental30                  0.298943         0.234211           -0.035489
# rental90                  0.327436         0.251029           -0.034122
# last_rech_date_ma         0.000870        -0.001123            0.002771
# last_rech_date_da         0.000519         0.001524           -0.002239
# last_rech_amt_ma          0.014067         0.148460            0.021004
# cnt_ma_rech30             0.685257         0.174104           -0.071451
# fr_ma_rech30              0.002634        -0.001890           -0.001292
# sumamnt_ma_rech30         0.484761         0.257705           -0.042244
# medianamnt_ma_rech30      0.014546         0.159613            0.022692
# medianmarechprebal30      0.000736        -0.002141           -0.001927
# cnt_ma_rech90             0.783419         0.244602           -0.072481
# fr_ma_rech90             -0.132035        -0.045780            0.016964
# sumamnt_ma_rech90         0.562609         0.321739           -0.042386
# medianamnt_ma_rech90     -0.023450         0.134139            0.031696
# medianmarechprebal90     -0.036412         0.027130            0.032453
# cnt_da_rech30             0.003369        -0.000647           -0.001365
# fr_da_rech30             -0.001593        -0.001069           -0.001623
# cnt_da_rech90             0.020909         0.038019           -0.003094
# fr_da_rech90              0.011501         0.021785           -0.000949
# cnt_loans30               0.852905         0.143590           -0.097871
# amnt_loans30              0.897961         0.329170           -0.087989
# maxamnt_loans30          -0.001850        -0.000487            0.009330
# medianamnt_loans30       -0.067580         0.058378            0.911604
# cnt_loans90               0.017697         0.001450           -0.002571
# amnt_loans90              1.000000         0.323417           -0.095160
# maxamnt_loans90           0.323417         1.000000            0.032256
# medianamnt_loans90       -0.095160         0.032256            1.000000
# payback30                 0.052142         0.013376           -0.013388
# payback90                 0.029653         0.029679           -0.010443
# pdate                     0.038509         0.015594           -0.000253
# pmonth                    0.318715         0.293784            0.011122
#
#                       payback30  payback90     pdate    pmonth
# label                  0.048336   0.049183  0.006825  0.154949
# aon                    0.001940   0.002203  0.000662 -0.001863
# daily_decr30           0.026915   0.047175  0.006477  0.518664
# daily_decr90           0.019400   0.040800 -0.021508  0.539410
# rental30               0.072974   0.095147  0.036537  0.365699
# rental90               0.067110   0.099501  0.008941  0.429407
# last_rech_date_ma     -0.002233  -0.001583  0.000560 -0.001207
# last_rech_date_da      0.000077   0.000417  0.000631 -0.001800
# last_rech_amt_ma      -0.027369  -0.014260  0.028883  0.096919
# cnt_ma_rech30          0.043617   0.017362  0.068643  0.156148
# fr_ma_rech30           0.001455   0.000998  0.000927 -0.001682
# sumamnt_ma_rech30      0.000112  -0.012596  0.056898  0.155682
# medianamnt_ma_rech30  -0.018398  -0.002861  0.039341  0.093037
# medianmarechprebal30   0.001516   0.001811 -0.002546  0.000272
# cnt_ma_rech90          0.011943  -0.003141  0.031852  0.340696
# fr_ma_rech90           0.036817   0.077529  0.009488 -0.026600
# sumamnt_ma_rech90     -0.026409  -0.029997  0.027564  0.315330
# medianamnt_ma_rech90  -0.035640  -0.023022  0.030696  0.088746
# medianmarechprebal90  -0.031760  -0.031210  0.002100  0.006627
# cnt_da_rech30         -0.000471   0.000382  0.003139  0.001845
# fr_da_rech30           0.001709  -0.000725  0.000538 -0.002303
# cnt_da_rech90          0.013430   0.024046  0.060286  0.023142
# fr_da_rech90           0.000354   0.001226  0.039979  0.013594
# cnt_loans30            0.067842   0.033369  0.077170  0.097415
# amnt_loans30           0.060425   0.030901  0.070131  0.162711
# maxamnt_loans30       -0.001512  -0.000915  0.002531 -0.003801
# medianamnt_loans30    -0.006007   0.003178 -0.003479  0.048908
# cnt_loans90            0.000587  -0.000476  0.001969  0.003577
# amnt_loans90           0.052142   0.029653  0.038509  0.318715
# maxamnt_loans90        0.013376   0.029679  0.015594  0.293784
# medianamnt_loans90    -0.013388  -0.010443 -0.000253  0.011122
# payback30              1.000000   0.830363  0.031514  0.064807
# payback90              0.830363   1.000000  0.025545  0.131380
# pdate                  0.031514   0.025545  1.000000 -0.252241
# pmonth                 0.064807   0.131380 -0.252241  1.000000
#
# [35 rows x 35 columns]

# %% [markdown]
# We can notice both positive and negative correlations between variables within the dataset. Let's try understanding data better using visualization.

# %%
#Plotting correlation of input features with the target Variable
plt.figure(figsize=(32,17))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')

# %% [markdown]
# Observations:
#
# Most features are positively correlated to the Target Variable "label" and hardly few attributes are negatively correlated.
#
# The most positively correlated variable to the target variable is 'cnt_ma_rech30' and 'cnt_ma_rech90'.
#
# The most negatively correlated variable to the target variable is 'fr_da_rech90'.
#
# Let's see correlations of input variables with the target variable in a sorted order.

# %%
#Sorting correlation in order with the Target Variable
corr_matrix=df.corr()
corr_matrix['label'].sort_values(ascending=False)
# Out:
# label                   1.000000
# cnt_ma_rech30           0.237331
# cnt_ma_rech90           0.236392
# sumamnt_ma_rech90       0.205793
# sumamnt_ma_rech30       0.202828
# amnt_loans90            0.199788
# amnt_loans30            0.197272
# cnt_loans30             0.196283
# daily_decr30            0.168298
# daily_decr90            0.166150
# pmonth                  0.154949
# medianamnt_ma_rech30    0.141490
# last_rech_amt_ma        0.131804
# medianamnt_ma_rech90    0.120855
# fr_ma_rech90            0.084385
# maxamnt_loans90         0.084144
# rental90                0.075521
# rental30                0.058085
# payback90               0.049183
# payback30               0.048336
# medianamnt_loans30      0.044589
# medianmarechprebal90    0.039300
# medianamnt_loans90      0.035747
# pdate                   0.006825
# cnt_loans90             0.004733
# cnt_da_rech30           0.003827
# last_rech_date_ma       0.003728
# cnt_da_rech90           0.002999
# last_rech_date_da       0.001711
# fr_ma_rech30            0.001330
# maxamnt_loans30         0.000248
# fr_da_rech30           -0.000027
# aon                    -0.003785
# medianmarechprebal30   -0.004829
# fr_da_rech90           -0.005418
# Name: label, dtype: float64

# %%
#Plotting Correlation in order with the target variable
plt.figure(figsize=(22,7))
df.corr()['label'].sort_values(ascending=False).drop(['label']).plot(kind='bar',color='y')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# From the above graph we cannot see any correlation of 'fr_da_rech30' and 'maxamnt_loans30' with the Target Variable 'label' and does not serve as much of importance to the data required for analysing it. Hence, we can drop the feature.
#
# Features 'aon','medianmarechprebal30' and 'fr_da_rech90' are negatively correlated to the target variable.
#
# All the other features are postively correlated to the target variable.

# %%
#Dropping the column 'fr_da_rech30' which does not serve as much importance
df.drop(['fr_da_rech30','maxamnt_loans30'],axis=1,inplace=True)

# %%
#Checking shape of dataframe
df.shape
# Out:
# (209593, 33)

# %% [markdown]
# # Checking skewness

# %%
#checking skewness
df.skew()
# Out:
# label                   -2.270254
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# medianamnt_loans30       4.551043
# cnt_loans90             16.594408
# amnt_loans90             3.150006
# maxamnt_loans90          1.678304
# medianamnt_loans90       4.895720
# payback30                8.310695
# payback90                6.899951
# pdate                    0.199845
# pmonth                   0.343242
# dtype: float64

# %% [markdown]
# Keeping threshold +/-0.5 as the range for skewness, we can see high skewness in almost every column of the dataset except the 'pdate' and 'pmonth' feature which explains the possibility of having huge outliers. Hence, we will treat the skewness present

# %%
#Visualizing skewness on density graph
#Example of multi variate analysis
df.plot(kind='density',subplots=True,layout=(4,10),legend=False,sharex=False,figsize=(40,20))
plt.show()

# %% [markdown]
# The values are observed to be 0 values mostly in almost all columns.
#
# The data is observed to have right skewness in almost all columns.
#
# The data does not have a normal distribution hence we will try to resolve skewness in data.

# %% [markdown]
# # Checking Outliers

# %%
#Visualizing outliers of different variables
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
#Visualizing outliers of different variables
collist=df.columns.values
ncol=6
nrows=10
plt.figure(figsize=(ncol,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='orange',orient='v')
    plt.tight_layout()

# %% [markdown]
# We can see too many outliers present in the dataset. Tried removing outliers but it is giving an information loss of 22.5% which is huge data, hence data removal is not preffered. So instead of removing outliers, data transformation is applied to normalize data.

# %% [markdown]
# # Separating the Column into x & y
# `

# %%
#Creating x & y columns 
x=df.drop('label',axis=1)
y=df['label']

# %% [markdown]
# Separating the columns into x & y as input featues and target variable respectively.

# %% [markdown]
# # Resolving Skewness using Power Transform

# %%
#Using power transform to remove skewness
from sklearn.preprocessing import power_transform
import warnings
warnings.filterwarnings('ignore')
hf=power_transform(x,method='yeo-johnson')

hf=pd.DataFrame(hf,columns=x.columns)

# %%
#Verifying skewness
hf.skew()
# Out:
# aon                       1.654517
# daily_decr30             -6.582717
# daily_decr90             -7.080193
# rental30                 -1.022844
# rental90                 -0.962717
# last_rech_date_ma        -5.362529
# last_rech_date_da      -106.606655
# last_rech_amt_ma         -0.061262
# cnt_ma_rech30            -0.000145
# fr_ma_rech30              0.165015
# sumamnt_ma_rech30        -0.291322
# medianamnt_ma_rech30     -0.189628
# medianmarechprebal30     -0.119058
# cnt_ma_rech90            -0.002465
# fr_ma_rech90              0.142952
# sumamnt_ma_rech90        -0.192158
# medianamnt_ma_rech90     -0.044604
# medianmarechprebal90      7.506286
# cnt_da_rech30             6.925820
# cnt_da_rech90             6.006577
# fr_da_rech90             15.469700
# cnt_loans30               0.036243
# amnt_loans30              0.001948
# medianamnt_loans30        3.447735
# cnt_loans90               0.105580
# amnt_loans90             -0.008988
# maxamnt_loans90           0.364282
# medianamnt_loans90        3.779598
# payback30                 0.298563
# payback90                 0.210887
# pdate                    -0.156079
# pmonth                    0.076431
# dtype: float64

# %% [markdown]
# Skewness in some features can be seen even after applying transformation methods. Hence, we will clean data getting into detail of each variable in which the skewness is observed.

# %% [markdown]
# # Normal Distribution Curve

# %%
sns.distplot(hf['last_rech_date_da'],kde=True)

# %%
sns.distplot(hf['fr_da_rech90'],kde=True)

# %%
sns.distplot(hf['medianmarechprebal90'],kde=True)

# %% [markdown]
# High Skewness is seen in features of all the above graphs so we will check it's correlation with target varaible, outliers present and skewness present in each column in order to clean data.

# %% [markdown]
# # Data Cleaning

# %%
#Making new dataframe
d=pd.DataFrame([["0.001711",'last_rech_date_da',"No","Alot"],["-0.005418",'fr_da_rech90',"No","Alot"],["0.039300",'medianmarechprebal90',"No","Alot"]],columns=["Correlation with Target","Column Name","Normalised","Outliers"])
d
# Out:
#   Correlation with Target           Column Name Normalised Outliers
# 0                0.001711     last_rech_date_da         No     Alot
# 1               -0.005418          fr_da_rech90         No     Alot
# 2                0.039300  medianmarechprebal90         No     Alot

# %% [markdown]
# Here, we are setting threshold of correlation as +/-0.5. From the above dataframe we can observe that the features in it have no good correlation with our target variable, does not show a normal distribution of data and has got a lot of outliers in it, hence these features does not contain any useful information for data analysis so we decide to drop them.

# %%
#deleting columns "last_rech_date_da","fr_da_rech90","medianmarechprebal90" from dataset
hf.drop(["last_rech_date_da","fr_da_rech90","medianmarechprebal90"],axis=1,inplace=True)

# %%
#Shape of existing dataframe
hf.shape
# Out:
# (209593, 29)

# %% [markdown]
# We have 209593 rows and 29 columns existing in the dataset.

# %%
x=hf

# %% [markdown]
# # Scaling Data Using Standard Scaler

# %%
#importing library for scaling
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
#Scaling our data to improve model performance
sc=StandardScaler()
x=sc.fit_transform(hf)
x
# Out:
# array([[-0.17711186,  0.33215599,  0.29918139, ...,  1.78396389,
#          0.71081705,  0.39752189],
#        [ 0.03645291,  1.11602076,  1.04508395, ..., -1.01891695,
#         -0.41015086,  1.48013263],
#        [-0.03465905, -0.00750824, -0.02820272, ..., -1.01891695,
#          0.60996673,  1.48013263],
#        ...,
#        [ 0.13457681,  1.10045476,  1.03342361, ...,  0.75293936,
#          1.54675655,  0.39752189],
#        [ 0.30910144,  1.13605674,  1.06838077, ...,  1.3378306 ,
#          1.18938459,  0.39752189],
#        [ 0.27706283,  0.52502127,  0.48715657, ..., -1.01891695,
#         -0.81941171,  0.39752189]])

# %% [markdown]
# Hence, the data is Scaled.

# %%
y.value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# y consists of 183431 records in 'label' "1" and 26162 records in 'label' "0". As we can see that the data is imbalanced in the target variable so Sampling techniques can be tried to handle the imbalance nature of target variablle.

# %% [markdown]
# # Model Building

# %%
#importing Libraries for buiding model
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
#Code for finding best random state
dt=DecisionTreeClassifier()
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    dt.fit(x_train,y_train)
    pred_train=dt.predict(x_train)
    pred_test=dt.predict(x_test)
    print(f'At random state {i}, the training accuracy is: {accuracy_score(y_train,pred_train)}')
    print(f'At random state {i}, the testing accuracy is: {accuracy_score(y_test,pred_test)}')
    print("\n")
# Out:
# At random state 0, the training accuracy is: 0.9999642162768229
# At random state 0, the testing accuracy is: 0.885588873780386
#
#
# At random state 1, the training accuracy is: 0.9999821081384115
# At random state 1, the testing accuracy is: 0.8842529640497149
#
#
# At random state 2, the training accuracy is: 0.9999761441845486
# At random state 2, the testing accuracy is: 0.8823445215773277
#
#
# At random state 3, the training accuracy is: 0.9999761441845486
# At random state 3, the testing accuracy is: 0.8830840430353778
#
#
# At random state 4, the training accuracy is: 0.99995825232296
# At random state 4, the testing accuracy is: 0.8862806841766263
#
#
# At random state 5, the training accuracy is: 0.9999701802306857
# At random state 5, the testing accuracy is: 0.8813425892793244
#
#
# At random state 6, the training accuracy is: 0.99995825232296
# At random state 6, the testing accuracy is: 0.884992485507765
#
#
# At random state 7, the training accuracy is: 0.9999642162768229
# At random state 7, the testing accuracy is: 0.8815095779956583
#
#
# At random state 8, the training accuracy is: 0.9999821081384115
# At random state 8, the testing accuracy is: 0.885135618693194
#
#
# At random state 9, the training accuracy is: 0.9999880720922742
# At random state 9, the testing accuracy is: 0.8838474200243326
#
#
# At random state 10, the training accuracy is: 0.9999701802306857
# At random state 10, the testing accuracy is: 0.8856842959040053
#
#
# At random state 11, the training accuracy is: 0.9999701802306857
# At random state 11, the testing accuracy is: 0.8837997089625229
#
#
# At random state 12, the training accuracy is: 0.9999821081384115
# At random state 12, the testing accuracy is: 0.8836327202461891
#
#
# At random state 13, the training accuracy is: 0.9999642162768229
# At random state 13, the testing accuracy is: 0.8837758534316181
#
#
# At random state 14, the training accuracy is: 0.9999642162768229
# At random state 14, the testing accuracy is: 0.8838951310861424
#
#
# At random state 15, the training accuracy is: 0.9999761441845486
# At random state 15, the testing accuracy is: 0.8838951310861424
#
#
# At random state 16, the training accuracy is: 0.9999701802306857
# At random state 16, the testing accuracy is: 0.885135618693194
#
#
# At random state 17, the training accuracy is: 0.9999642162768229
# At random state 17, the testing accuracy is: 0.885732006965815
#
#
# At random state 18, the training accuracy is: 0.9999642162768229
# At random state 18, the testing accuracy is: 0.8835134425916649
#
#
# At random state 19, the training accuracy is: 0.9999761441845486
# At random state 19, the testing accuracy is: 0.8858274290894343
#
#
# At random state 20, the training accuracy is: 0.9999642162768229
# At random state 20, the testing accuracy is: 0.8842291085188101
#
#
# At random state 21, the training accuracy is: 0.9999701802306857
# At random state 21, the testing accuracy is: 0.8848732078532408
#
#
# At random state 22, the training accuracy is: 0.9999821081384115
# At random state 22, the testing accuracy is: 0.8835850091843794
#
#
# At random state 23, the training accuracy is: 0.9999701802306857
# At random state 23, the testing accuracy is: 0.8834657315298552
#
#
# At random state 24, the training accuracy is: 0.9999761441845486
# At random state 24, the testing accuracy is: 0.8839666976788568
#
#
# At random state 25, the training accuracy is: 0.9999701802306857
# At random state 25, the testing accuracy is: 0.8840621198024762
#
#
# At random state 26, the training accuracy is: 0.9999701802306857
# At random state 26, the testing accuracy is: 0.8848254967914311
#
#
# At random state 27, the training accuracy is: 0.9999761441845486
# At random state 27, the testing accuracy is: 0.8833703094062358
#
#
# At random state 28, the training accuracy is: 0.9999761441845486
# At random state 28, the testing accuracy is: 0.8847777857296214
#
#
# At random state 29, the training accuracy is: 0.9999761441845486
# At random state 29, the testing accuracy is: 0.8847539301987166
#
#
# At random state 30, the training accuracy is: 0.9999761441845486
# At random state 30, the testing accuracy is: 0.8835372981225698
#
#
# At random state 31, the training accuracy is: 0.9999642162768229
# At random state 31, the testing accuracy is: 0.8883799708962523
#
#
# At random state 32, the training accuracy is: 0.9999821081384115
# At random state 32, the testing accuracy is: 0.8861614065221022
#
#
# At random state 33, the training accuracy is: 0.9999821081384115
# At random state 33, the testing accuracy is: 0.8854695961258617
#
#
# At random state 34, the training accuracy is: 0.9999761441845486
# At random state 34, the testing accuracy is: 0.8847539301987166
#
#
# At random state 35, the training accuracy is: 0.9999701802306857
# At random state 35, the testing accuracy is: 0.8853980295331473
#
#
# At random state 36, the training accuracy is: 0.99995825232296
# At random state 36, the testing accuracy is: 0.8863761063002457
#
#
# At random state 37, the training accuracy is: 0.99995825232296
# At random state 37, the testing accuracy is: 0.8843722417042391
#
#
# At random state 38, the training accuracy is: 0.9999701802306857
# At random state 38, the testing accuracy is: 0.8836327202461891
#
#
# At random state 39, the training accuracy is: 0.9999821081384115
# At random state 39, the testing accuracy is: 0.882153677330089
#
#
# At random state 40, the training accuracy is: 0.9999642162768229
# At random state 40, the testing accuracy is: 0.8865669505474845
#
#
# At random state 41, the training accuracy is: 0.9999761441845486
# At random state 41, the testing accuracy is: 0.8852310408168134
#
#
# At random state 42, the training accuracy is: 0.9999701802306857
# At random state 42, the testing accuracy is: 0.8835611536534745
#
#
# At random state 43, the training accuracy is: 0.9999701802306857
# At random state 43, the testing accuracy is: 0.8858035735585296
#
#
# At random state 44, the training accuracy is: 0.9999821081384115
# At random state 44, the testing accuracy is: 0.8822729549846132
#
#
# At random state 45, the training accuracy is: 0.9999701802306857
# At random state 45, the testing accuracy is: 0.8834180204680455
#
#
# At random state 46, the training accuracy is: 0.9999701802306857
# At random state 46, the testing accuracy is: 0.8853264629404327
#
#
# At random state 47, the training accuracy is: 0.9999701802306857
# At random state 47, the testing accuracy is: 0.8836088647152842
#
#
# At random state 48, the training accuracy is: 0.99995825232296
# At random state 48, the testing accuracy is: 0.8841813974570004
#
#
# At random state 49, the training accuracy is: 0.9999761441845486
# At random state 49, the testing accuracy is: 0.8847539301987166
#
#
# At random state 50, the training accuracy is: 0.9999761441845486
# At random state 50, the testing accuracy is: 0.8835611536534745
#
#
# At random state 51, the training accuracy is: 0.9999642162768229
# At random state 51, the testing accuracy is: 0.8857797180276247
#
#
# At random state 52, the training accuracy is: 0.99995825232296
# At random state 52, the testing accuracy is: 0.8826784990099955
#
#
# At random state 53, the training accuracy is: 0.9999642162768229
# At random state 53, the testing accuracy is: 0.8827262100718052
#
#
# At random state 54, the training accuracy is: 0.9999701802306857
# At random state 54, the testing accuracy is: 0.8830840430353778
#
#
# At random state 55, the training accuracy is: 0.9999761441845486
# At random state 55, the testing accuracy is: 0.882296810515518
#
#
# At random state 56, the training accuracy is: 0.9999701802306857
# At random state 56, the testing accuracy is: 0.886781650325628
#
#
# At random state 57, the training accuracy is: 0.9999701802306857
# At random state 57, the testing accuracy is: 0.8822252439228035
#
#
# At random state 58, the training accuracy is: 0.9999940360461371
# At random state 58, the testing accuracy is: 0.8860898399293876
#
#
# At random state 59, the training accuracy is: 0.9999821081384115
# At random state 59, the testing accuracy is: 0.885732006965815
#
#
# At random state 60, the training accuracy is: 0.9999701802306857
# At random state 60, the testing accuracy is: 0.885732006965815
#
#
# At random state 61, the training accuracy is: 0.9999880720922742
# At random state 61, the testing accuracy is: 0.882893198788139
#
#
# At random state 62, the training accuracy is: 0.9999761441845486
# At random state 62, the testing accuracy is: 0.8852071852859086
# At random state 63, the training accuracy is: 0.9999701802306857
# At random state 63, the testing accuracy is: 0.8865430950165796
#
#
# At random state 64, the training accuracy is: 0.9999761441845486
# At random state 64, the testing accuracy is: 0.8829170543190439
#
#
# At random state 65, the training accuracy is: 0.9999761441845486
# At random state 65, the testing accuracy is: 0.8842052529879052
#
#
# At random state 66, the training accuracy is: 0.9999880720922742
# At random state 66, the testing accuracy is: 0.8872349054128199
#
#
# At random state 67, the training accuracy is: 0.9999821081384115
# At random state 67, the testing accuracy is: 0.8859705622748635
#
#
# At random state 68, the training accuracy is: 0.9999701802306857
# At random state 68, the testing accuracy is: 0.8877835826236313
#
#
# At random state 69, the training accuracy is: 0.9999701802306857
# At random state 69, the testing accuracy is: 0.8847539301987166
#
#
# At random state 70, the training accuracy is: 0.9999761441845486
# At random state 70, the testing accuracy is: 0.8826784990099955
#
#
# At random state 71, the training accuracy is: 0.9999761441845486
# At random state 71, the testing accuracy is: 0.8864476728929602
#
#
# At random state 72, the training accuracy is: 0.9999642162768229
# At random state 72, the testing accuracy is: 0.8881652711181087
#
#
# At random state 73, the training accuracy is: 0.9999701802306857
# At random state 73, the testing accuracy is: 0.8842768195806198
#
#
# At random state 74, the training accuracy is: 0.9999642162768229
# At random state 74, the testing accuracy is: 0.8851117631622891
#
#
# At random state 75, the training accuracy is: 0.9999701802306857
# At random state 75, the testing accuracy is: 0.8861136954602925
#
#
# At random state 76, the training accuracy is: 0.9999701802306857
# At random state 76, the testing accuracy is: 0.8846346525441924
#
#
# At random state 77, the training accuracy is: 0.9999880720922742
# At random state 77, the testing accuracy is: 0.8840382642715714
#
#
# At random state 78, the training accuracy is: 0.9999761441845486
# At random state 78, the testing accuracy is: 0.8841813974570004
#
#
# At random state 79, the training accuracy is: 0.9999701802306857
# At random state 79, the testing accuracy is: 0.8853026074095279
#
#
# At random state 80, the training accuracy is: 0.9999642162768229
# At random state 80, the testing accuracy is: 0.8841336863951907
#
#
# At random state 81, the training accuracy is: 0.9999761441845486
# At random state 81, the testing accuracy is: 0.8862091175839119
#
#
# At random state 82, the training accuracy is: 0.9999642162768229
# At random state 82, the testing accuracy is: 0.885445740594957
#
#
# At random state 83, the training accuracy is: 0.9999821081384115
# At random state 83, the testing accuracy is: 0.8824637992318519
#
#
# At random state 84, the training accuracy is: 0.9999821081384115
# At random state 84, the testing accuracy is: 0.8858512846203392
#
#
# At random state 85, the training accuracy is: 0.9999701802306857
# At random state 85, the testing accuracy is: 0.8826784990099955
#
#
# At random state 86, the training accuracy is: 0.9999761441845486
# At random state 86, the testing accuracy is: 0.8860659843984828
#
#
# At random state 87, the training accuracy is: 0.9999701802306857
# At random state 87, the testing accuracy is: 0.8850401965695747
#
#
# At random state 88, the training accuracy is: 0.9999821081384115
# At random state 88, the testing accuracy is: 0.8808893341921324
#
#
# At random state 89, the training accuracy is: 0.9999701802306857
# At random state 89, the testing accuracy is: 0.8837042868389036
#
#
# At random state 90, the training accuracy is: 0.9999642162768229
# At random state 90, the testing accuracy is: 0.88201054414466
#
#
# At random state 91, the training accuracy is: 0.9999761441845486
# At random state 91, the testing accuracy is: 0.8860659843984828
#
#
# At random state 92, the training accuracy is: 0.9999701802306857
# At random state 92, the testing accuracy is: 0.8869724945728668
#
#
# At random state 93, the training accuracy is: 0.9999880720922742
# At random state 93, the testing accuracy is: 0.8849209189150504
#
#
# At random state 94, the training accuracy is: 0.9999642162768229
# At random state 94, the testing accuracy is: 0.8828454877263293
#
#
# At random state 95, the training accuracy is: 0.9999761441845486
# At random state 95, the testing accuracy is: 0.885278751878623
#
#
# At random state 96, the training accuracy is: 0.9999761441845486
# At random state 96, the testing accuracy is: 0.8850879076313843
#
#
# At random state 97, the training accuracy is: 0.9999701802306857
# At random state 97, the testing accuracy is: 0.8849686299768601
#
#
# At random state 98, the training accuracy is: 0.9999701802306857
# At random state 98, the testing accuracy is: 0.884396097235144
#
#
# At random state 99, the training accuracy is: 0.9999761441845486
# At random state 99, the testing accuracy is: 0.8833941649371406

# %% [markdown]
# Best random state selected is 31.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=31)

# %% [markdown]
# We split our data into Training and Testing giving 78% data for Training and 22% for Testing at random state 31. We will use different algorithms for comparing accuracies and attaining the best model. We will compare Logitic Regression, DecisionTreeClassifier, GaussianNB, KNeighborsClassifier and RandomForestClassifier in this case.

# %% [markdown]
# # Over Sampling

# %%
#!pip install imbalanced-learn

# %%
#Importing libraries
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
Counter(y_train)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-61-ec4633a7eb40> in <module>
#       1 #Importing libraries
# ----> 2 from imblearn.over_sampling import RandomOverSampler
#       3 from collections import Counter
#       4 Counter(y_train)
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
#Creating object and fitting train samples using Oversampling
os=RandomOverSampler(0.8)
x_train_ns,y_train_ns=os.fit_resample(x_train,y_train)
print("The number of classes before fit {}".format(Counter(y_train)))
print("The number of classes after fit {}".format(Counter(y_train_ns)))

# %% [markdown]
# The number of classes before fit Counter({1: 142969, 0: 20513})
# The number of classes after fit Counter({1: 142969, 0: 114375})

# %%
#Object creation for all classifiers 
lr=LogisticRegression()
gnb=GaussianNB()
dt=DecisionTreeClassifier()
kn=KNeighborsClassifier()
rf=RandomForestClassifier()

# %%
model=[LogisticRegression(),GaussianNB(),DecisionTreeClassifier(),KNeighborsClassifier()]

# %%
for m in model:
    m.fit(x_train_ns,y_train_ns)
    m.score(x_train_ns,y_train_ns)
    predm=m.predict(x_test)
    print('Accuracy score of',m,'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')

# %% [markdown]
# We get an accuracy of -
#
# 78.21% in Logistic Regression
# 72.27% Gaussian NB
# 88.97% Decision Tree
# 82.88% KNeighbors Classifiers
#
# But the accuracy isn't enough especially when the data is imbalanced so looking at other metrics such as precision, recall and f1 score, the model is not performing so well. Let's try ensemble techniques and hypertuning these models to attain better performance metrics.

# %% [markdown]
# #### Ensemble Techniques

# %%
#Importing libraries and perform training
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train_ns,y_train_ns)

# %%
#Performing predictions
y_pred=rf.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# The performance of Random Forest can be seen to be better comparing other models. Let's use hypertuning on these algorithms.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
#Importing Libarary for Hyper Parameter Tuning SearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import KFold

# %% [markdown]
# ##### Logistic Regression

# %%
#Finding best parameters
parameters={'C':10.0 **np.arange(-2,3),'penalty':['l1','l2'],'multi_class':['auto','ovr']}
cv=KFold(n_splits=9,random_state=None,shuffle=False)
clf=RandomizedSearchCV(lr,parameters,cv=cv,scoring='f1_macro')
clf.fit(x_train_ns,y_train_ns)

print(clf.best_params_)

# %%
#Predicting results
y_pred=clf.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# There is no improvement in the performance of Logistic Regression because the precision and f1 score is very low.

# %% [markdown]
# ##### Gaussian NB

# %%
#Finding best parameters
parameters={'var_smoothing': np.logspace(0,-9, num=100)}
cv=KFold(n_splits=9,random_state=None,shuffle=False)
clf1=RandomizedSearchCV(gnb,parameters,cv=cv,scoring='accuracy')
clf1.fit(x_train_ns,y_train_ns)

print(clf1.best_params_)

# %%
#Predicting results
y_pred=clf1.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# The precision and f1 score of Gaussian Nb is also very low, hence no good performnce.

# %% [markdown]
# ##### Decision Tree Classifier

# %%
#Finding best parameters
parameters={"criterion":["gini","entropy"],'max_depth':np.arange(2,15),"max_features":np.arange(1, 9),'min_samples_leaf':np.arange(3,9)}
cv=KFold(n_splits=9,random_state=None,shuffle=False)
clf2=RandomizedSearchCV(dt,parameters,cv=cv,scoring='accuracy')
clf2.fit(x_train_ns,y_train_ns)

print(clf2.best_params_)

# %%
#Predicting results
y_pred=clf2.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# Performance of decision tree is better than any other algorithm, but the precision and f1 score is still less.

# %% [markdown]
# ##### Random Forest Classifier

# %%
#Finding best parameters
parameters={"criterion":["gini","entropy"],"max_features":["auto","sqrt"],"max_depth":np.arange(1, 28, 1)}
cv=KFold(n_splits=5,random_state=None,shuffle=False)
clf3=RandomizedSearchCV(rf,parameters,cv=cv,scoring='accuracy')
clf3.fit(x_train_ns,y_train_ns)

print(clf3.best_params_)

# %%
#Predicting results
y_pred=clf3.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# The accuracy obtained for Random Forest is 92% which is the best out of any other algorithms and also the performance of other metrics such as precision, recall and f1 score is better than any other algorithms used for model Training. We get the best results from Random Forest, hence we use Random Forest Classifier for this dataset.

# %% [markdown]
# # Plotting AUC ROC Curve

# %%
#Importing libraries to plot auc roc curve
from sklearn.metrics import roc_curve,auc
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score

# %%
#Creating AUC ROC curve for Random Forest Classifier
clf3.fit(x,y)
y_pred_prob=clf3.predict_proba(x_test)[:,1]
y_pred_prob
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
roc_auc=auc(fpr,tpr)

# %%
#Plotting Graph
plt.plot([0,1],[0,1],color='navy',lw=10,linestyle='--')
plt.plot(fpr,tpr,color='darkorange',lw=10,label='ROC curve (area= %0.2f)'%roc_auc)
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('Falsepositive rate')
plt.ylabel('True positive rate')
plt.title('Random Forest Classifier')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# We get auc roc score as 100% which means our model is working rightly. The higher the AUC, the better the performance of the model at distinguishing between the positive and negative classes.

# %% [markdown]
# # Saving the Best Model

# %%
#Saving the best model
import pickle
filename='credit.pkl'
pickle.dump(clf3,open(filename,'wb'))
